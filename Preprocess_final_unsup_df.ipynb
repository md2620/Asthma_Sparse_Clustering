# %%
import pandas as pd
#Load libraries
from sklearn.preprocessing import PowerTransformer
import numpy as np
from kmodes.kprototypes import KPrototypes
#Load libraries
from matplotlib import style
from lightgbm import LGBMClassifier
import shap
from sklearn.model_selection import cross_val_score
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
#Load library
from sklearn.preprocessing import LabelEncoder
import os
import random
# Out:
# /apps/jupyterhub/2019-04-29/miniconda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /apps/jupyterhub/2019-04-29/miniconda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /apps/jupyterhub/2019-04-29/miniconda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %% [markdown]
# PREPROCESSING df_unsup_not_processed : Unsupervised clustering

# %%
#Import dataset for supervised clustering
df_unsup_unprocess = pd.read_csv('/rds/general/user/md2620/home/asthma/Malo/Dataframes/Final/df_unsup_not_processed.csv', low_memory=False)

# %%
#Check if there are variables necessiting removal
df_unsup_unprocess.head(5)
# Out:
#   Unnamed: 0  Biomarker.C5a.pg.ml.serum  Biomarker.CD30.pg.ml.serum  \
# 0      A_237                         30                          77
# 1      A_132                         21                          37
# 2      A_074                         32                          46
# 3      A_335                         66                          38
# 4      A_418                         44                          41
#
#    Biomarker.CD40L.pg.ml.serum  Biomarker.DPPIV.pg.ml.serum  \
# 0                         7395                       119595
# 1                         7517                        80984
# 2                         6775                       216071
# 3                         3334                        91777
# 4                         3925                       200474
#
#    Biomarker.Galectin.3.pg.ml.serum  Biomarker.IL.18.pg.ml.serum  \
# 0                              6497                          558
# ...

# %%
#Set Unnamed: 0 as index of df_unsup_unprocess
df_unsup_unprocess = df_unsup_unprocess.set_index('Unnamed: 0')

# %%
#Check variable types for specific columns using:
pd.options.display.max_columns = None
pd.options.display.max_rows = None
df_unsup_unprocess.iloc[:,0:180].dtypes
# Out:
# Biomarker.C5a.pg.ml.serum                                                int64
# Biomarker.CD30.pg.ml.serum                                               int64
# Biomarker.CD40L.pg.ml.serum                                              int64
# Biomarker.DPPIV.pg.ml.serum                                              int64
# Biomarker.Galectin.3.pg.ml.serum                                         int64
# Biomarker.IL.18.pg.ml.serum                                              int64
# Biomarker.IL.1alpha.pg.ml.serum                                          int64
# Biomarker.IL.6Ralpha.pg.ml.serum                                         int64
# Biomarker.LBP.pg.ml.serum                                                int64
# Biomarker.Lumican.pg.ml.serum                                            int64
# Biomarker.MCP.4.pg.ml.serum                                              int64
# Biomarker.MMP.3.pg.ml.serum                                              int64
# ...

# %%
#Standardize using yeo-johnson transformation numerical variables
from sklearn.preprocessing import PowerTransformer
for c in df_unsup_unprocess.iloc[:,0:180]:
    pt = PowerTransformer()
    df_unsup_unprocess[c] =  pt.fit_transform(np.array(df_unsup_unprocess[c]).reshape(-1, 1))
# Out:
# divide by zero encountered in log
# divide by zero encountered in log
# divide by zero encountered in log
# divide by zero encountered in log
# divide by zero encountered in log
# divide by zero encountered in log
# divide by zero encountered in log
# divide by zero encountered in log
# divide by zero encountered in log
# divide by zero encountered in log
# divide by zero encountered in log
# divide by zero encountered in log
# divide by zero encountered in log
# divide by zero encountered in log
# divide by zero encountered in log
# divide by zero encountered in log

# %%
#Save dataset for unsupervised K-proto in R
os.chdir("/rds/general/user/md2620/home/asthma/Malo/Dataframes/Final")
df_unsup_unprocess.to_csv("df_unsup_num_processed.csv")

# %% [markdown]
# FINAL PREPROCESSING DF UNSUP

# %%
#Import dataset to process cat variables after having run unsupervised K-prototypes (K= 2 to 15 in R)
#Needing to construct shap and run K-proto in Python + to run PCA
df_unsup_partial_process = pd.read_csv('/rds/general/user/md2620/home/asthma/Malo/Dataframes/Final/unsup_df.csv', low_memory=False)

# %%
df_unsup_partial_process.head(5)
# Out:
#   Unnamed: 0  Biomarker.C5a.pg.ml.serum  Biomarker.CD30.pg.ml.serum  \
# 0      A_237                  -0.389563                    1.594876
# 1      A_132                  -0.903106                    0.051530
# 2      A_074                  -0.283828                    0.565457
# 3      A_335                   1.242211                    0.117235
# 4      A_418                   0.304558                    0.300170
#
#    Biomarker.CD40L.pg.ml.serum  Biomarker.DPPIV.pg.ml.serum  \
# 0                     1.189472                     0.548141
# 1                     1.238507                    -0.428928
# 2                     0.937791                     2.490261
# 3                    -0.560012                    -0.137712
# 4                    -0.286963                     2.208245
#
#    Biomarker.Galectin.3.pg.ml.serum  Biomarker.IL.18.pg.ml.serum  \
# 0                          0.386750                     2.247782
# ...

# %%
#Check variable types for specific columns using:
pd.options.display.max_columns = None
pd.options.display.max_rows = None
df_unsup_partial_process.iloc[:,181:362].dtypes
# Out:
# Asthma.Diag.Fev.Variation                                   object
# Asthma.Diag.Pef.Variation                                   object
# Asthma.Diag.Historic.Test                                   object
# Expo.Aspirin                                                object
# Expo.Barns                                                  object
# Expo.Cold.Air                                               object
# Expo.Dust                                                   object
# Expo.Fungus                                                 object
# Expo.Menstrual.Cycle                                        object
# Expo.Perfumes                                               object
# Expo.Pets                                                   object
# Expo.Physical.Exercise                                      object
# Expo.Pollen                                                 object
# Expo.Pollutants                                             object
# ...

# %%
#Convert range of variables 181-362 to str
df_unsup_partial_process.iloc[:,181:362]=df_unsup_partial_process.iloc[:,181:362].astype('str')

# %%
#Label encode categorical variables
from sklearn import preprocessing
for c in df_unsup_partial_process.iloc[:,181:362]:
    le = preprocessing.LabelEncoder()
    df_unsup_partial_process[c] = le.fit_transform(np.array(df_unsup_partial_process[c]).reshape(-1, 1))
# Out:
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().

# %%
#Standardize using yeo-johnson transformation for all variables in df to be scaled identically
from sklearn.preprocessing import PowerTransformer
for c in df_unsup_partial_process.iloc[:,181:362]:
    pt = PowerTransformer()
    df_unsup_partial_process[c] =  pt.fit_transform(np.array(df_unsup_partial_process[c]).reshape(-1, 1))

# %%
df_unsup_partial_process.head(5)
# Out:
#   Unnamed: 0  Biomarker.C5a.pg.ml.serum  Biomarker.CD30.pg.ml.serum  \
# 0      A_237                  -0.389563                    1.594876
# 1      A_132                  -0.903106                    0.051530
# 2      A_074                  -0.283828                    0.565457
# 3      A_335                   1.242211                    0.117235
# 4      A_418                   0.304558                    0.300170
#
#    Biomarker.CD40L.pg.ml.serum  Biomarker.DPPIV.pg.ml.serum  \
# 0                     1.189472                     0.548141
# 1                     1.238507                    -0.428928
# 2                     0.937791                     2.490261
# 3                    -0.560012                    -0.137712
# 4                    -0.286963                     2.208245
#
#    Biomarker.Galectin.3.pg.ml.serum  Biomarker.IL.18.pg.ml.serum  \
# 0                          0.386750                     2.247782
# ...

# %%
#Save final unsupervised dataset with processing of cat variables
os.chdir("/rds/general/user/md2620/home/asthma/Malo/Dataframes/Final")
df_unsup_partial_process.to_csv("unsup_df_all_processed.csv")
