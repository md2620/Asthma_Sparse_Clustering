# %%
import pandas as pd

# %% [markdown]
# Load clinical data

# %%
df=pd.read_csv('/rds/general/user/md2620/home/asthma/Data/data_clinical.tsv', sep='\t', low_memory=False)

# %% [markdown]
# Look at shape of the dataset

# %%
df.shape
# Out:
# (620, 3543)

# %%
#Check first five rows of dataframe
df.head(5)
# Out:
#   Subject ID  \
# 0      A_275
# 1      A_255
# 2      A_066
# 3      A_576
# 4      A_346
#
#   \UBIOPRED\Adult_Cohort_(Jan_2019)\Asthma Diagnosis\Diagnosis Fev Variation\  \
# 0                                                yes
# 1                                                NaN
# 2                                                NaN
# 3                                                 no
# 4                                                 no
#
#   \UBIOPRED\Adult_Cohort_(Jan_2019)\Asthma Diagnosis\Diagnosis Pef Variation\  \
# 0                                                 no
# 1                                                NaN
# 2                                                NaN
# 3                                                 no
# 4                                                 no
#
#    \UBIOPRED\Adult_Cohort_(Jan_2019)\Asthma Diagnosis\Historic Test No Methacoline\  \
# 0                                                NaN
# ...

# %%
#Check to what classes your variables belong
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 620 entries, 0 to 619
# Columns: 3543 entries, Subject ID to \UBIOPRED\Adult_Cohort_(Jan_2019)\Visit Information\Longitudinal Visit\Days Since Screening (Longitudinal Visit)\
# dtypes: float64(2805), object(738)
# memory usage: 16.8+ MB

# %% [markdown]
# If you want to check what columns names are

# %%
df.columns
# Out:
# Index(['Subject ID',
#        '\UBIOPRED\Adult_Cohort_(Jan_2019)\Asthma Diagnosis\Diagnosis Fev Variation\',
#        '\UBIOPRED\Adult_Cohort_(Jan_2019)\Asthma Diagnosis\Diagnosis Pef Variation\',
#        '\UBIOPRED\Adult_Cohort_(Jan_2019)\Asthma Diagnosis\Historic Test No Methacoline\',
#        '\UBIOPRED\Adult_Cohort_(Jan_2019)\Asthma Diagnosis\Historic Test No Reversibility\',
#        '\UBIOPRED\Adult_Cohort_(Jan_2019)\Asthma Diagnosis\Historic Test Yes Methacholine\',
#        '\UBIOPRED\Adult_Cohort_(Jan_2019)\Asthma Diagnosis\Historic Test Yes Reversibility\',
#        '\UBIOPRED\Adult_Cohort_(Jan_2019)\Asthma Diagnosis\Historic Test\',
#        '\UBIOPRED\Adult_Cohort_(Jan_2019)\Asthma Diagnosis\Methacholine Challenge Test\Methacoline Performed With\',
#        '\UBIOPRED\Adult_Cohort_(Jan_2019)\Atopy Exposures and Triggers\Baseline\Aspirin\',
#        ...
#        '\UBIOPRED\Adult_Cohort_(Jan_2019)\Subject History\Respiratory History\Pneumonia X Ray\',
# ...

# %%
for col in df.columns:
    print(col)
# Out:
# Subject ID
# \UBIOPRED\Adult_Cohort_(Jan_2019)\Asthma Diagnosis\Diagnosis Fev Variation\
# \UBIOPRED\Adult_Cohort_(Jan_2019)\Asthma Diagnosis\Diagnosis Pef Variation\
# \UBIOPRED\Adult_Cohort_(Jan_2019)\Asthma Diagnosis\Historic Test No Methacoline\
# \UBIOPRED\Adult_Cohort_(Jan_2019)\Asthma Diagnosis\Historic Test No Reversibility\
# \UBIOPRED\Adult_Cohort_(Jan_2019)\Asthma Diagnosis\Historic Test Yes Methacholine\
# \UBIOPRED\Adult_Cohort_(Jan_2019)\Asthma Diagnosis\Historic Test Yes Reversibility\
# \UBIOPRED\Adult_Cohort_(Jan_2019)\Asthma Diagnosis\Historic Test\
# \UBIOPRED\Adult_Cohort_(Jan_2019)\Asthma Diagnosis\Methacholine Challenge Test\Methacoline Performed With\
# \UBIOPRED\Adult_Cohort_(Jan_2019)\Atopy Exposures and Triggers\Baseline\Aspirin\
# \UBIOPRED\Adult_Cohort_(Jan_2019)\Atopy Exposures and Triggers\Baseline\Barns\
# \UBIOPRED\Adult_Cohort_(Jan_2019)\Atopy Exposures and Triggers\Baseline\Cold Air\
# ...

# %% [markdown]
# Check pourcentage of missing values per column.
# Try to keep only columns with more than 80% available data, so less than 20% missing values

# %%
new = df.isnull().sum().sort_values(ascending=False)/len(df)

# %%
new.drop(new[df.isnull().sum().sort_values(ascending=False)/len(df)>0.20].index,inplace=True)

# %%
new
# Out:
# \UBIOPRED\Adult_Cohort_(Jan_2019)\Subject Clusters\Classification by eosinophil count\tertile cutoff\               0.2
# \UBIOPRED\Adult_Cohort_(Jan_2019)\Subject Clusters\Classification by eosinophil count\eosinophils (per uL)\         0.2
# \UBIOPRED\Adult_Cohort_(Jan_2019)\Subject Clusters\Classification by eosinophil count\eosinophils (10^3 per uL)\    0.2
# \UBIOPRED\Adult_Cohort_(Jan_2019)\Subject Clusters\Classification by eosinophil count\eosinophil tertiles\          0.2
# \UBIOPRED\Adult_Cohort_(Jan_2019)\Subject Clusters\Classification by eosinophil count\eosinophil clinical level\    0.2
#                                                                                                                    ...
# \UBIOPRED\Adult_Cohort_(Jan_2019)\Subject History\Medical or Surgical History\Allergic Rhinitis Diagnosed\          0.0
# \UBIOPRED\Adult_Cohort_(Jan_2019)\Questions\Screening\Food Allergies\Food Allergy\                                  0.0
# ...

# %%
new.shape
# Out:
# (550,)

# %%
df.shape
# Out:
# (620, 3543)

# %%
df.dropna(thresh=0.8*len(df), axis=1, inplace=True)

# %%
df.shape
# Out:
# (620, 550)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 620 entries, 0 to 619
# Columns: 550 entries, Subject ID to \UBIOPRED\Adult_Cohort_(Jan_2019)\Visit Information\Baseline Visit\Days Since Screening (Baseline Day 2)\
# dtypes: float64(391), object(159)
# memory usage: 2.6+ MB

# %% [markdown]
# Write a dataset with variables having less than 20% missingness

# %%
df.to_csv(r'/rds/general/user/md2620/home/asthma/Malo/Dataframes/asthma_clinical_20%missingness.csv',index=True)

# %%
for col in df.columns:
    print(col)
# Out:
# Subject ID
# \UBIOPRED\Adult_Cohort_(Jan_2019)\Asthma Diagnosis\Diagnosis Fev Variation\
# \UBIOPRED\Adult_Cohort_(Jan_2019)\Asthma Diagnosis\Diagnosis Pef Variation\
# \UBIOPRED\Adult_Cohort_(Jan_2019)\Asthma Diagnosis\Historic Test\
# \UBIOPRED\Adult_Cohort_(Jan_2019)\Atopy Exposures and Triggers\Baseline\Aspirin\
# \UBIOPRED\Adult_Cohort_(Jan_2019)\Atopy Exposures and Triggers\Baseline\Barns\
# \UBIOPRED\Adult_Cohort_(Jan_2019)\Atopy Exposures and Triggers\Baseline\Cold Air\
# \UBIOPRED\Adult_Cohort_(Jan_2019)\Atopy Exposures and Triggers\Baseline\Dust\
# \UBIOPRED\Adult_Cohort_(Jan_2019)\Atopy Exposures and Triggers\Baseline\Fungus\
# \UBIOPRED\Adult_Cohort_(Jan_2019)\Atopy Exposures and Triggers\Baseline\Menstrual Cycle\
# \UBIOPRED\Adult_Cohort_(Jan_2019)\Atopy Exposures and Triggers\Baseline\Other1\
# \UBIOPRED\Adult_Cohort_(Jan_2019)\Atopy Exposures and Triggers\Baseline\Other2\
# \UBIOPRED\Adult_Cohort_(Jan_2019)\Atopy Exposures and Triggers\Baseline\Other3\
# ...

# %%
df.isnull().sum().reset_index(name="n").plot.bar(x='index', y='n', rot=45)

# %%
target = df['\UBIOPRED\Adult_Cohort_(Jan_2019)\ClinicalData\SeriousAdverseEvent\Event12\Outcome event\']
# Out:
#   File "<ipython-input-43-952576d36a3f>", line 1
#     target = df['\UBIOPRED\Adult_Cohort_(Jan_2019)\ClinicalData\SeriousAdverseEvent\Event12\Outcome event\']
#                                                                                                             ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# If you find your target/outcome variable (add supervision to your clustering)

# %%
#Create target variable
#target = df['casecont']
#Drop casecont once target is created
#df.drop('casecont', axis = 1, inplace = True)

# %% [markdown]
# SPLIT THE DATASET

# %%
#Split the dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df,target,test_size=0.25, random_state=12)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-59e1c837cb4e> in <module>
#       1 #Split the dataset
#       2 from sklearn.model_selection import train_test_split
# ----> 3 X_train, X_test, y_train, y_test = train_test_split(df,target,test_size=0.25, random_state=12)
#
# NameError: name 'target' is not defined

# %%
target = df['\UBIOPRED\Adult_Cohort_(Jan_2019)\Clinical Data\Serious Adverse Event\Event 4\Outcome event\']
# Out:
#   File "<ipython-input-46-64fb10a99667>", line 1
#     target = df['\UBIOPRED\Adult_Cohort_(Jan_2019)\Clinical Data\Serious Adverse Event\Event 4\Outcome event\']
#                                                                                                                ^
# SyntaxError: EOL while scanning string literal

# %%
target = df\UBIOPRED\Adult_Cohort_(Jan_2019)\Asthma Diagnosis\Diagnosis Fev Variation\
# Out:
#   File "<ipython-input-47-e0c9d2d2097b>", line 1
#     target = df\UBIOPRED\Adult_Cohort_(Jan_2019)\Asthma Diagnosis\Diagnosis Fev Variation\
#                                                                                           ^
# SyntaxError: unexpected character after line continuation character

# %%
df2 = df.iloc[:,0:100]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 620 entries, 0 to 619
# Data columns (total 100 columns):
#  #   Column                                                                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                                                                     --------------  -----
#  0   Subject ID                                                                                                                                 620 non-null    object
#  1   \UBIOPRED\Adult_Cohort_(Jan_2019)\Asthma Diagnosis\Diagnosis Fev Variation\                                                                519 non-null    object
#  2   \UBIOPRED\Adult_Cohort_(Jan_2019)\Asthma Diagnosis\Diagnosis Pef Variation\                                                                518 non-null    object
# ...

# %%
df2.head(10)
# Out:
#   Subject ID  \
# 0      A_275
# 1      A_255
# 2      A_066
# 3      A_576
# 4      A_346
# 5      A_069
# 6      A_377
# 7      A_149
# 8      A_072
# 9      A_664
#
#   \UBIOPRED\Adult_Cohort_(Jan_2019)\Asthma Diagnosis\Diagnosis Fev Variation\  \
# 0                                                yes
# 1                                                NaN
# 2                                                NaN
# 3                                                 no
# 4                                                 no
# 5                                                 no
# 6                                                yes
# 7                                                 no
# 8                                                 no
# 9                                                 no
#
#   \UBIOPRED\Adult_Cohort_(Jan_2019)\Asthma Diagnosis\Diagnosis Pef Variation\  \
# 0                                                 no
# 1                                                NaN
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 620 entries, 0 to 619
# Data columns (total 100 columns):
#  #   Column                                                                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                                                                     --------------  -----
#  0   Subject ID                                                                                                                                 620 non-null    object
#  1   \UBIOPRED\Adult_Cohort_(Jan_2019)\Asthma Diagnosis\Diagnosis Fev Variation\                                                                519 non-null    object
#  2   \UBIOPRED\Adult_Cohort_(Jan_2019)\Asthma Diagnosis\Diagnosis Pef Variation\                                                                518 non-null    object
# ...

# %%
#Split X_train into two dataframes - one with only numerical variables and the other one with only categorical variables.
df2_numerical = df2.select_dtypes(include='float64')
df2_categorical = df2.select_dtypes(include='object')

# %%
#Look for NAs in the 2 dataframes before imputation
print(df2_numerical.isnull().sum().sum())
print(df2_categorical.isnull().sum().sum())
# Out:
# 8456
# 10178

# %%
#For numerical columns in df2 replace by mean of each column all NAs in that column
df2_numerical.fillna(df2_numerical.mean(), inplace=True)
# Out:
# /rds/general/user/md2620/home/.local/lib/python3.6/site-packages/pandas/core/generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
#Check that you have no NAs in your numerical dataframes anymore
print(df2_numerical.isnull().sum().sum())
# Out:
# 0

# %%
#Load required package
import numpy as np

# %%
#Constant impute for categorical variables
from sklearn.impute import SimpleImputer
# Creating an imputer object that looks for 'Nan' values, then replaces them with missing_value for categorical variables
miss_constant_imputer = SimpleImputer(missing_values=np.nan, strategy='most_frequent', copy=False)
df2_categorical = pd.DataFrame(miss_constant_imputer.fit_transform(df2_categorical),index = df2_categorical.index.values, columns=df2_categorical.columns)

# %%
#Check number of NAs in df2_categorical after imputation
print(df2_categorical.isnull().sum().sum())
# Out:
# 0

# %% [markdown]
# NORMALIZE THE NUMERICAL VARIABLES

# %%
from sklearn.preprocessing import StandardScaler

# %%
#Normalize X_train_numerical
sc = StandardScaler()
sc.fit(df2_numerical)
df2_numerical = pd.DataFrame(sc.transform(df2_numerical), index = df2_numerical.index, columns = df2_numerical.columns)

# %%
df2_numerical.head(5)
# Out:
#    \UBIOPRED\Adult_Cohort_(Jan_2019)\Asthma Diagnosis\Historic Test No Methacoline\  \
# 0                                       6.495281e-17
# 1                                       6.495281e-17
# 2                                       6.495281e-17
# 3                                       6.495281e-17
# 4                                       4.139654e+00
#
#    \UBIOPRED\Adult_Cohort_(Jan_2019)\Asthma Diagnosis\Historic Test No Reversibility\  \
# 0                                      -3.985023e-16
# 1                                      -3.985023e-16
# 2                                      -3.985023e-16
# 3                                      -3.985023e-16
# 4                                      -2.785989e+00
#
#    \UBIOPRED\Adult_Cohort_(Jan_2019)\Asthma Diagnosis\Historic Test Yes Methacholine\  \
# 0                                      -7.235848e-01
# 1                                       1.171538e-16
# 2                                       1.171538e-16
# ...

# %% [markdown]
# RECONCILE CATEGORICAL AND NUMERICAL DATAFRAMES

# %%
#Now that imputation has been successfully made for both numerical and categorical variables, 
#Merge back df2_categorical and df2_numerical and rename it to df2_new. 
df2_new = pd.concat([df2_numerical, df2_categorical], axis=1)

# %%
df2_new.shape
# Out:
# (620, 100)

# %%
#Make sure you have no null values in both datasets after concatenate
print(df2_new.isnull().sum().sum())
# Out:
# 0
